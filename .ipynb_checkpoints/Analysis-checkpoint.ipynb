# %% [markdown]
# # DATA

# %%
import savReaderWriter as sav
import pandas as pd
import chardet
import pyreadstat as prs
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
base = open(r'_data/censo_interh.csv', 'rb').read()
det = chardet.detect(base)
charenc = det['encoding']
charenc
# Out:
# 'UTF-8-SIG'

# %%
data = pd.read_csv(r'_data/censo_interh.csv', encoding = charenc, thousands = ' ', dtype = {'Código': str})

# %%
data.dtypes
# Out:
# Código                          object
# Distrito                        object
# Sí tiene conexión a internet     int64
# No tiene conexión a internet     int64
# dtype: object

# %%
data['Departamento'] = data.loc[:, 'Distrito'].copy().str.split(', ').apply(lambda row: row[ 0 ])
data
# Out:
#       Código                                           Distrito  \
# 0      10101       Amazonas, Chachapoyas, distrito: Chachapoyas
# 1      10102          Amazonas, Chachapoyas, distrito: Asunción
# 2      10103            Amazonas, Chachapoyas, distrito: Balsas
# 3      10104             Amazonas, Chachapoyas, distrito: Cheto
# 4      10105         Amazonas, Chachapoyas, distrito: Chiliquin
# ...      ...                                                ...
# 1869  250302             Ucayali, Padre Abad, distrito: Irazola
# 1870  250303            Ucayali, Padre Abad, distrito: Curimana
# 1871  250304             Ucayali, Padre Abad, distrito: Neshuya
# 1872  250305  Ucayali, Padre Abad, distrito: Alexander Von H...
# 1873  250401                    Ucayali, Purús, distrito: Purús
#
#       Sí tiene conexión a internet  No tiene conexión a internet Departamento
# 0                             1534                          6825     Amazonas
# ...

# %%
data[ 'Provincia' ] = data.loc[ :, 'Distrito' ].copy().str.split( ', ' ).apply( lambda row: row[ 1 ] )
data
# Out:
#       Código                                           Distrito  \
# 0      10101       Amazonas, Chachapoyas, distrito: Chachapoyas
# 1      10102          Amazonas, Chachapoyas, distrito: Asunción
# 2      10103            Amazonas, Chachapoyas, distrito: Balsas
# 3      10104             Amazonas, Chachapoyas, distrito: Cheto
# 4      10105         Amazonas, Chachapoyas, distrito: Chiliquin
# ...      ...                                                ...
# 1869  250302             Ucayali, Padre Abad, distrito: Irazola
# 1870  250303            Ucayali, Padre Abad, distrito: Curimana
# 1871  250304             Ucayali, Padre Abad, distrito: Neshuya
# 1872  250305  Ucayali, Padre Abad, distrito: Alexander Von H...
# 1873  250401                    Ucayali, Purús, distrito: Purús
#
#       Sí tiene conexión a internet  No tiene conexión a internet Departamento  \
# 0                             1534                          6825     Amazonas
# ...

# %%
data['Distrito'] = data.loc[ :, 'Distrito' ].copy().str.split( 'distrito: ' ).apply( lambda row: row[ 1 ] )
data
# Out:
#       Código                Distrito  Sí tiene conexión a internet  \
# 0      10101             Chachapoyas                          1534
# 1      10102                Asunción                             0
# 2      10103                  Balsas                             3
# 3      10104                   Cheto                             6
# 4      10105               Chiliquin                             0
# ...      ...                     ...                           ...
# 1869  250302                 Irazola                            70
# 1870  250303                Curimana                            22
# 1871  250304                 Neshuya                            61
# 1872  250305  Alexander Von Humboldt                            30
# 1873  250401                   Purús                             3
#
#       No tiene conexión a internet Departamento    Provincia
# 0                             6825     Amazonas  Chachapoyas
# ...

# %%
def correct_ubigeo(string):
    if len(string) == 5:
        string = '0' + string
    return string

# %%
data.loc[:, 'Código'] = data.apply(lambda row: correct_ubigeo(row['Código']), axis = 1)

# %%
data = data.rename(columns = {'Sí tiene conexión a internet':'int_con_yes', 'No tiene conexión a internet':'int_con_no'})

# %%
data['Total'] = data['int_con_yes'] + data['int_con_no']

# %%
data['prop_int_yes'] = data['int_con_yes'] / data['Total']

# %% [markdown]
# # GEODATA

# %%
shp_distritos = gpd.read_file(r'_data/LIMITE_DISTRITAL_2020_INEI/INEI_LIMITE_DISTRITAL.shp')

# %%
shp_distritos
# Out:
#      CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0      06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1      06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2      06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3      06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4      06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
# ...   ...        ...  ...         ...  ...           ...              ...
# 1869   04   AREQUIPA   04    CASTILLA   04       CHACHAS          CHACHAS
# 1870   04   AREQUIPA   04    CASTILLA   05  CHILCAYMARCA     CHILCAYMARCA
# 1871   04   AREQUIPA   04    CASTILLA   06         CHOCO            CHOCO
# 1872   04   AREQUIPA   04    CASTILLA   07    HUANCARQUI       HUANCARQUI
# 1873   12      JUNIN   06      SATIPO   04      MAZAMARI             None
#
#       UBIGEO IDPROV  CODIGO  CNT_CCPP    DESCRIPCIO           DESCARGAR  \
# ...

# %%
geo_data = shp_distritos.merge(data, left_on = 'UBIGEO', right_on = 'Código')
geo_data
# Out:
#      CCDD    NOMBDEP CCPP    NOMBPROV CCDI      NOMBDIST          CAPITAL  \
# 0      06  CAJAMARCA   05   CONTUMAZA   04      GUZMANGO         GUZMANGO
# 1      06  CAJAMARCA   11  SAN MIGUEL   05      EL PRADO         EL PRADO
# 2      06  CAJAMARCA   11  SAN MIGUEL   09        NIEPOS           NIEPOS
# 3      06  CAJAMARCA   11  SAN MIGUEL   10  SAN GREGORIO     SAN GREGORIO
# 4      06  CAJAMARCA   12   SAN PABLO   03      SAN LUIS  SAN LUIS GRANDE
# ...   ...        ...  ...         ...  ...           ...              ...
# 1869   04   AREQUIPA   04    CASTILLA   04       CHACHAS          CHACHAS
# 1870   04   AREQUIPA   04    CASTILLA   05  CHILCAYMARCA     CHILCAYMARCA
# 1871   04   AREQUIPA   04    CASTILLA   06         CHOCO            CHOCO
# 1872   04   AREQUIPA   04    CASTILLA   07    HUANCARQUI       HUANCARQUI
# 1873   12      JUNIN   06      SATIPO   04      MAZAMARI             None
#
#       UBIGEO IDPROV  CODIGO  ...                  CONTACTO  \
# ...

# %%
geo_data.plot(cmap = plt.cm.YlOrRd, column = 'prop_int_yes', figsize = (20, 20), legend = True, legend_kwds = dict(label = 'Proportion of households with internet connection in 2017, by district'))
# Out:
# <AxesSubplot:>

# %%
geo_data_mercator = gpd.GeoDataFrame(dict(UBIGEO = geo_data.UBIGEO, 
                                          Total = geo_data.Total,
                                          tau_yes = geo_data.int_con_yes,
                                          tau_no = geo_data.int_con_no,
                                          pi_yes = geo_data.prop_int_yes,
                                          pi_no = 1 - geo_data.prop_int_yes,
                                          geometry = geo_data.geometry.to_crs(3857), 
                                          centroids = geo_data.geometry.to_crs(3857).centroid))

# %%
geo_data_mercator
# Out:
#       UBIGEO  Total  tau_yes  tau_no    pi_yes     pi_no  \
# 0     060504    875        1     874  0.001143  0.998857
# 1     061105    549        0     549  0.000000  1.000000
# 2     061109   1113        7    1106  0.006289  0.993711
# 3     061110    760        1     759  0.001316  0.998684
# 4     061203    327        1     326  0.003058  0.996942
# ...      ...    ...      ...     ...       ...       ...
# 1869  040404    498        2     496  0.004016  0.995984
# 1870  040405    304        6     298  0.019737  0.980263
# 1871  040406    299        0     299  0.000000  1.000000
# 1872  040407    516       38     478  0.073643  0.926357
# 1873  120604   7742      400    7342  0.051666  0.948334
#
#                                                geometry  \
# 0     POLYGON ((-8784864.068 -817180.227, -8784633.4...
# 1     POLYGON ((-8796109.160 -777756.324, -8796000.1...
# 2     POLYGON ((-8818386.499 -764553.397, -8818258.2...
# ...

# %%
geo_data_mercator.plot(cmap = plt.cm.YlOrRd, column = 'pi_yes', figsize = (20, 20), legend = True, legend_kwds = dict(label = 'Proportion of households with internet connection in 2017, by district'))
# Out:
# <AxesSubplot:>

# %%
dist_matrix = geo_data_mercator.centroids.apply(lambda g: geo_data_mercator.centroids.distance(g))

# %%
for i in range(len(dist_matrix)):
    dist_matrix.iloc[i, i] = dist_matrix.iloc[i, i] + 1

# %%
dist_matrix
# Out:
#               0             1             2             3             4     \
# 0     1.000000e+00  2.643520e-05  1.833010e-05  2.584151e-05  4.244005e-05
# 1     2.643520e-05  1.000000e+00  5.275808e-05  5.073725e-05  5.035202e-05
# 2     1.833010e-05  5.275808e-05  1.000000e+00  4.607543e-05  2.576709e-05
# 3     2.584151e-05  5.073725e-05  4.607543e-05  1.000000e+00  3.088530e-05
# 4     4.244005e-05  5.035202e-05  2.576709e-05  3.088530e-05  1.000000e+00
# ...            ...           ...           ...           ...           ...
# 1869  8.568350e-07  8.324719e-07  8.196995e-07  8.293983e-07  8.463517e-07
# 1870  8.598639e-07  8.350011e-07  8.222163e-07  8.323026e-07  8.489056e-07
# 1871  8.396598e-07  8.161335e-07  8.038749e-07  8.133159e-07  8.294502e-07
# 1872  8.164863e-07  7.936958e-07  7.822210e-07  7.917010e-07  8.061665e-07
# 1873  1.431057e-06  1.368730e-06  1.334144e-06  1.356110e-06  1.406975e-06
#
# ...

# %% [markdown]
# # Measures with quadratic decay

# %%
phi_matrix = 1 / (dist_matrix ** 2)

# %%
PHI = phi_matrix.sum(axis = 1)

# %%
phi_matrix = phi_matrix.to_numpy()

# %%
phi_matrix.shape
# Out:
# (1874, 1874)

# %%
PHI = PHI.to_numpy()

# %%
tau = geo_data_mercator.Total
tau = tau.to_numpy()
tau.shape
# Out:
# (1874,)

# %%
tau_yes = geo_data_mercator.tau_yes
tau_no = geo_data_mercator.tau_no

# %%
tau_yes = tau_yes.to_numpy()
tau_yes.shape
# Out:
# (1874,)

# %%
tau_local = np.dot(phi_matrix * PHI, tau)

# %%
tau_yes_local = np.dot(phi_matrix * PHI, tau_yes)

# %%
tau_yes_local
# Out:
# array([1.00004725e+00, 4.23446561e-05, 7.00004119e+00, ...,
#        1.57718732e-05, 3.80000231e+01, 4.00000032e+02])

# %%
pi_yes_local = tau_yes_local / tau_local
pi_yes_local
# Out:
# array([1.14291073e-03, 7.71304760e-08, 6.28934309e-03, ...,
#        5.27487255e-08, 7.36434406e-02, 5.16662383e-02])

# %%
geo_data_mercator['pi_yes_local'] = pi_yes_local

# %%
geo_data_mercator.plot(cmap = plt.cm.YlOrRd, column = 'pi_yes_local', figsize = (20, 20), legend = True, legend_kwds = dict(label = 'Local environment proportion for each district'))
plt.title('Ye', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Ye')

# %%
local_entropy = - (pi_yes_local * np.log2(pi_yes_local)) - ((1 - pi_yes_local) * np.log2(1 - pi_yes_local))

# %%
local_entropy.shape
# Out:
# (1874,)

# %%
geo_data_mercator['local_entropy'] = local_entropy

# %%
geo_data_mercator.plot(cmap = plt.cm.YlOrRd, column = 'local_entropy', figsize = (20, 20), legend = True, legend_kwds = dict(label = 'Local Entropy Measure'))
plt.title('Local entropy measure of the proportion of households with/without an internet connection at the district level', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Local entropy measure of the proportion of households with/without an internet connection at the district level')

# %%
pi_yes_total = tau_yes.sum() / (tau_yes.sum() + tau_no.sum())

# %%
pi_yes_total
# Out:
# 0.2804292726716628

# %%
total_entropy = - (pi_yes_total * np.log2(pi_yes_total)) - ((1 - pi_yes_total) * np.log2(1 - pi_yes_total))
total_entropy
# Out:
# 0.8560350655073441

# %%
spatial_info = 1 - np.dot(tau.T, local_entropy) / (tau.sum() * total_entropy)
spatial_info
# Out:
# 0.22732940538402446

# %% [markdown]
# # Measures with adjacency decay
